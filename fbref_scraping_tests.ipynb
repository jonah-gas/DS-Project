# %%
from fbref_scraping import Fbref

# create scraper class instance
scraper = Fbref()

# %%
# test .get_squad_match_data_df()
#df = scraper.get_squad_match_data_df(squad_index, league_index, season_start_year, print_logs=True)

# %%
#df.shape
#df
#for col in df.columns:
#    print(col)

# %%
#test get_squad_id_df()
season_start_year = 2017
league_index = 12 

df = scraper.get_squad_id_df(league_index, season_start_year, print_logs=True)
# Out:
# Retrieving data from https://fbref.com/en/comps/12/2017-2018.

# %%
df
# Out:
#     squad_id           squad_name
# 0   206d90db            Barcelona
# 1   db3b9613      Atletico Madrid
# 2   53a2f082          Real Madrid
# 3   dcc91a7b             Valencia
# 4   2a8183b3           Villarreal
# 5   fc536746           Real Betis
# 6   ad2be733              Sevilla
# 7   7848bd64               Getafe
# 8   bea5c710                Eibar
# 9   9024a00a               Girona
# 10  a8661628             Espanyol
# 11  e31d1cd9        Real Sociedad
# 12  f25da7fb           Celta Vigo
# 13  8d6fd021               Alaves
# 14  9800b6a1              Levante
# 15  2b390eca        Athletic Club
# 16  7c6f2c78              Leganes
# 17  2a60ed82  Deportivo La Coruna
# 18  0049d422           Las Palmas
# 19  1c896955               Malaga
