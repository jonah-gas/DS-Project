# %%
from fbref_scraping import Fbref

# create scraper class instance
scraper = Fbref()

# %%
# test .get_squad_match_data_df()
squad_id = '1c896955'
season_start_year = 2017
league_id = 12 
df = scraper.get_squad_match_data_df(squad_id, league_id, season_start_year, print_logs=True)
# Out:
# Retrieving data from https://fbref.com/en/squads/1c896955/2017-2018/matchlogs/c12/schedule.
# Retrieving data from https://fbref.com/en/squads/1c896955/2017-2018/matchlogs/c12/shooting.
# Retrieving data from https://fbref.com/en/squads/1c896955/2017-2018/matchlogs/c12/keeper.
# Retrieving data from https://fbref.com/en/squads/1c896955/2017-2018/matchlogs/c12/passing.
# Retrieving data from https://fbref.com/en/squads/1c896955/2017-2018/matchlogs/c12/passing_types.
# Retrieving data from https://fbref.com/en/squads/1c896955/2017-2018/matchlogs/c12/gca.
# Retrieving data from https://fbref.com/en/squads/1c896955/2017-2018/matchlogs/c12/defense.
# Retrieving data from https://fbref.com/en/squads/1c896955/2017-2018/matchlogs/c12/possession.
# Retrieving data from https://fbref.com/en/squads/1c896955/2017-2018/matchlogs/c12/misc.

# %%
df.shape
#df
#for col in df.columns:
#    print(col)
# Out:
# (38, 170)

# %%
#test get_squad_id_df()
season_start_year = 2017
league_id = 12 

df = scraper.get_squad_id_df(league_id, season_start_year, print_logs=True)
df
# Out:
# Retrieving data from https://fbref.com/en/comps/12/2017-2018.

# %%
# test get_league_match_data()
season_start_year = 2017
league_id = 12 

# with return_df=True and save_csv=True we should get a dataframe as well as a csv file saved in the default path: 'data/scraped/fbref
# note: the path must exist in our local directory, it won't be created by the function. The most recent git commit should have the path created.

# optionally, we can also specify a different output directory (either relative to the notebook directory or a full path) when creating the scraper instance, e.g.:
#scraper = Fbref(output_dir=r'C:\Users\Jan Jacobsen\Desktop')

df = scraper.get_league_match_data_df(league_id, season_start_year, return_df=True, save_csv=True, print_logs=True)
# Out:
# Retrieved 20 squad_ids for league_id=12, season_start_year=2017.
# Starting data collection for squad 1/20: Barcelona (id: 206d90db)
# Retrieving data from https://fbref.com/en/squads/206d90db/2017-2018/matchlogs/c12/schedule.
# Retrieving data from https://fbref.com/en/squads/206d90db/2017-2018/matchlogs/c12/shooting.
# Retrieving data from https://fbref.com/en/squads/206d90db/2017-2018/matchlogs/c12/keeper.
# Retrieving data from https://fbref.com/en/squads/206d90db/2017-2018/matchlogs/c12/passing.
# Retrieving data from https://fbref.com/en/squads/206d90db/2017-2018/matchlogs/c12/passing_types.
# Retrieving data from https://fbref.com/en/squads/206d90db/2017-2018/matchlogs/c12/gca.
# Retrieving data from https://fbref.com/en/squads/206d90db/2017-2018/matchlogs/c12/defense.
# Retrieving data from https://fbref.com/en/squads/206d90db/2017-2018/matchlogs/c12/possession.
# Retrieving data from https://fbref.com/en/squads/206d90db/2017-2018/matchlogs/c12/misc.
# Starting data collection for squad 2/20: Atletico Madrid (id: db3b9613)
# Retrieving data from https://fbref.com/en/squads/db3b9613/2017-2018/matchlogs/c12/schedule.
# Retrieving data from https://fbref.com/en/squads/db3b9613/2017-2018/matchlogs/c12/shooting.
# Retrieving data from https://fbref.com/en/squads/db3b9613/2017-2018/matchlogs/c12/keeper.
# Retrieving data from https://fbref.com/en/squads/db3b9613/2017-2018/matchlogs/c12/passing.
# Retrieving data from https://fbref.com/en/squads/db3b9613/2017-2018/matchlogs/c12/passing_types.
# Retrieving data from https://fbref.com/en/squads/db3b9613/2017-2018/matchlogs/c12/gca.
# Retrieving data from https://fbref.com/en/squads/db3b9613/2017-2018/matchlogs/c12/defense.
# Retrieving data from https://fbref.com/en/squads/db3b9613/2017-2018/matchlogs/c12/possession.
# Retrieving data from https://fbref.com/en/squads/db3b9613/2017-2018/matchlogs/c12/misc.
# Starting data collection for squad 3/20: Real Madrid (id: 53a2f082)
# Retrieving data from https://fbref.com/en/squads/53a2f082/2017-2018/matchlogs/c12/schedule.
# Retrieving data from https://fbref.com/en/squads/53a2f082/2017-2018/matchlogs/c12/shooting.
# Retrieving data from https://fbref.com/en/squads/53a2f082/2017-2018/matchlogs/c12/keeper.
# Retrieving data from https://fbref.com/en/squads/53a2f082/2017-2018/matchlogs/c12/passing.
# Retrieving data from https://fbref.com/en/squads/53a2f082/2017-2018/matchlogs/c12/passing_types.
# Retrieving data from https://fbref.com/en/squads/53a2f082/2017-2018/matchlogs/c12/gca.
# Retrieving data from https://fbref.com/en/squads/53a2f082/2017-2018/matchlogs/c12/defense.
# Retrieving data from https://fbref.com/en/squads/53a2f082/2017-2018/matchlogs/c12/possession.
# Retrieving data from https://fbref.com/en/squads/53a2f082/2017-2018/matchlogs/c12/misc.
# Starting data collection for squad 4/20: Valencia (id: dcc91a7b)
# Retrieving data from https://fbref.com/en/squads/dcc91a7b/2017-2018/matchlogs/c12/schedule.
# Retrieving data from https://fbref.com/en/squads/dcc91a7b/2017-2018/matchlogs/c12/shooting.
# Retrieving data from https://fbref.com/en/squads/dcc91a7b/2017-2018/matchlogs/c12/keeper.
# Retrieving data from https://fbref.com/en/squads/dcc91a7b/2017-2018/matchlogs/c12/passing.
# Retrieving data from https://fbref.com/en/squads/dcc91a7b/2017-2018/matchlogs/c12/passing_types.
# Retrieving data from https://fbref.com/en/squads/dcc91a7b/2017-2018/matchlogs/c12/gca.
# Retrieving data from https://fbref.com/en/squads/dcc91a7b/2017-2018/matchlogs/c12/defense.
# Retrieving data from https://fbref.com/en/squads/dcc91a7b/2017-2018/matchlogs/c12/possession.
# Retrieving data from https://fbref.com/en/squads/dcc91a7b/2017-2018/matchlogs/c12/misc.
# Starting data collection for squad 5/20: Villarreal (id: 2a8183b3)
# Retrieving data from https://fbref.com/en/squads/2a8183b3/2017-2018/matchlogs/c12/schedule.
# Retrieving data from https://fbref.com/en/squads/2a8183b3/2017-2018/matchlogs/c12/shooting.
# Retrieving data from https://fbref.com/en/squads/2a8183b3/2017-2018/matchlogs/c12/keeper.
# Retrieving data from https://fbref.com/en/squads/2a8183b3/2017-2018/matchlogs/c12/passing.
# Retrieving data from https://fbref.com/en/squads/2a8183b3/2017-2018/matchlogs/c12/passing_types.
# Retrieving data from https://fbref.com/en/squads/2a8183b3/2017-2018/matchlogs/c12/gca.
# Retrieving data from https://fbref.com/en/squads/2a8183b3/2017-2018/matchlogs/c12/defense.
# Retrieving data from https://fbref.com/en/squads/2a8183b3/2017-2018/matchlogs/c12/possession.
# Retrieving data from https://fbref.com/en/squads/2a8183b3/2017-2018/matchlogs/c12/misc.
# Starting data collection for squad 6/20: Real Betis (id: fc536746)
# Retrieving data from https://fbref.com/en/squads/fc536746/2017-2018/matchlogs/c12/schedule.
# Retrieving data from https://fbref.com/en/squads/fc536746/2017-2018/matchlogs/c12/shooting.
# Retrieving data from https://fbref.com/en/squads/fc536746/2017-2018/matchlogs/c12/keeper.
# Retrieving data from https://fbref.com/en/squads/fc536746/2017-2018/matchlogs/c12/passing.
# Retrieving data from https://fbref.com/en/squads/fc536746/2017-2018/matchlogs/c12/passing_types.
# Retrieving data from https://fbref.com/en/squads/fc536746/2017-2018/matchlogs/c12/gca.
# Retrieving data from https://fbref.com/en/squads/fc536746/2017-2018/matchlogs/c12/defense.
# Retrieving data from https://fbref.com/en/squads/fc536746/2017-2018/matchlogs/c12/possession.
# Retrieving data from https://fbref.com/en/squads/fc536746/2017-2018/matchlogs/c12/misc.
# Starting data collection for squad 7/20: Sevilla (id: ad2be733)
# Retrieving data from https://fbref.com/en/squads/ad2be733/2017-2018/matchlogs/c12/schedule.
# Retrieving data from https://fbref.com/en/squads/ad2be733/2017-2018/matchlogs/c12/shooting.
# Retrieving data from https://fbref.com/en/squads/ad2be733/2017-2018/matchlogs/c12/keeper.
# Retrieving data from https://fbref.com/en/squads/ad2be733/2017-2018/matchlogs/c12/passing.
# Retrieving data from https://fbref.com/en/squads/ad2be733/2017-2018/matchlogs/c12/passing_types.
# Retrieving data from https://fbref.com/en/squads/ad2be733/2017-2018/matchlogs/c12/gca.
# Retrieving data from https://fbref.com/en/squads/ad2be733/2017-2018/matchlogs/c12/defense.
# Retrieving data from https://fbref.com/en/squads/ad2be733/2017-2018/matchlogs/c12/possession.
# Retrieving data from https://fbref.com/en/squads/ad2be733/2017-2018/matchlogs/c12/misc.
# Starting data collection for squad 8/20: Getafe (id: 7848bd64)
# Retrieving data from https://fbref.com/en/squads/7848bd64/2017-2018/matchlogs/c12/schedule.
# Retrieving data from https://fbref.com/en/squads/7848bd64/2017-2018/matchlogs/c12/shooting.
# Retrieving data from https://fbref.com/en/squads/7848bd64/2017-2018/matchlogs/c12/keeper.
# Retrieving data from https://fbref.com/en/squads/7848bd64/2017-2018/matchlogs/c12/passing.
# Retrieving data from https://fbref.com/en/squads/7848bd64/2017-2018/matchlogs/c12/passing_types.
# Retrieving data from https://fbref.com/en/squads/7848bd64/2017-2018/matchlogs/c12/gca.
# Retrieving data from https://fbref.com/en/squads/7848bd64/2017-2018/matchlogs/c12/defense.
# Retrieving data from https://fbref.com/en/squads/7848bd64/2017-2018/matchlogs/c12/possession.
# Retrieving data from https://fbref.com/en/squads/7848bd64/2017-2018/matchlogs/c12/misc.
# Starting data collection for squad 9/20: Eibar (id: bea5c710)
# Retrieving data from https://fbref.com/en/squads/bea5c710/2017-2018/matchlogs/c12/schedule.
# Retrieving data from https://fbref.com/en/squads/bea5c710/2017-2018/matchlogs/c12/shooting.
# Retrieving data from https://fbref.com/en/squads/bea5c710/2017-2018/matchlogs/c12/keeper.
# Retrieving data from https://fbref.com/en/squads/bea5c710/2017-2018/matchlogs/c12/passing.
# Retrieving data from https://fbref.com/en/squads/bea5c710/2017-2018/matchlogs/c12/passing_types.
# Retrieving data from https://fbref.com/en/squads/bea5c710/2017-2018/matchlogs/c12/gca.
# Retrieving data from https://fbref.com/en/squads/bea5c710/2017-2018/matchlogs/c12/defense.
# Retrieving data from https://fbref.com/en/squads/bea5c710/2017-2018/matchlogs/c12/possession.
# Retrieving data from https://fbref.com/en/squads/bea5c710/2017-2018/matchlogs/c12/misc.
# Starting data collection for squad 10/20: Girona (id: 9024a00a)
# Retrieving data from https://fbref.com/en/squads/9024a00a/2017-2018/matchlogs/c12/schedule.
# Retrieving data from https://fbref.com/en/squads/9024a00a/2017-2018/matchlogs/c12/shooting.
# Retrieving data from https://fbref.com/en/squads/9024a00a/2017-2018/matchlogs/c12/keeper.
# Retrieving data from https://fbref.com/en/squads/9024a00a/2017-2018/matchlogs/c12/passing.
# Retrieving data from https://fbref.com/en/squads/9024a00a/2017-2018/matchlogs/c12/passing_types.
# Retrieving data from https://fbref.com/en/squads/9024a00a/2017-2018/matchlogs/c12/gca.
# Retrieving data from https://fbref.com/en/squads/9024a00a/2017-2018/matchlogs/c12/defense.
# Retrieving data from https://fbref.com/en/squads/9024a00a/2017-2018/matchlogs/c12/possession.
# Retrieving data from https://fbref.com/en/squads/9024a00a/2017-2018/matchlogs/c12/misc.
# Starting data collection for squad 11/20: Espanyol (id: a8661628)
# Retrieving data from https://fbref.com/en/squads/a8661628/2017-2018/matchlogs/c12/schedule.
# Retrieving data from https://fbref.com/en/squads/a8661628/2017-2018/matchlogs/c12/shooting.
# Retrieving data from https://fbref.com/en/squads/a8661628/2017-2018/matchlogs/c12/keeper.
# Retrieving data from https://fbref.com/en/squads/a8661628/2017-2018/matchlogs/c12/passing.
# Retrieving data from https://fbref.com/en/squads/a8661628/2017-2018/matchlogs/c12/passing_types.
# Retrieving data from https://fbref.com/en/squads/a8661628/2017-2018/matchlogs/c12/gca.
# Retrieving data from https://fbref.com/en/squads/a8661628/2017-2018/matchlogs/c12/defense.
# Retrieving data from https://fbref.com/en/squads/a8661628/2017-2018/matchlogs/c12/possession.
# Retrieving data from https://fbref.com/en/squads/a8661628/2017-2018/matchlogs/c12/misc.
# Starting data collection for squad 12/20: Real Sociedad (id: e31d1cd9)
# Retrieving data from https://fbref.com/en/squads/e31d1cd9/2017-2018/matchlogs/c12/schedule.
# Retrieving data from https://fbref.com/en/squads/e31d1cd9/2017-2018/matchlogs/c12/shooting.
# Retrieving data from https://fbref.com/en/squads/e31d1cd9/2017-2018/matchlogs/c12/keeper.
# Retrieving data from https://fbref.com/en/squads/e31d1cd9/2017-2018/matchlogs/c12/passing.
# Retrieving data from https://fbref.com/en/squads/e31d1cd9/2017-2018/matchlogs/c12/passing_types.
# Retrieving data from https://fbref.com/en/squads/e31d1cd9/2017-2018/matchlogs/c12/gca.
# Retrieving data from https://fbref.com/en/squads/e31d1cd9/2017-2018/matchlogs/c12/defense.
# Retrieving data from https://fbref.com/en/squads/e31d1cd9/2017-2018/matchlogs/c12/possession.
# Retrieving data from https://fbref.com/en/squads/e31d1cd9/2017-2018/matchlogs/c12/misc.
# Starting data collection for squad 13/20: Celta Vigo (id: f25da7fb)
# Retrieving data from https://fbref.com/en/squads/f25da7fb/2017-2018/matchlogs/c12/schedule.
# Retrieving data from https://fbref.com/en/squads/f25da7fb/2017-2018/matchlogs/c12/shooting.
# Retrieving data from https://fbref.com/en/squads/f25da7fb/2017-2018/matchlogs/c12/keeper.
# Retrieving data from https://fbref.com/en/squads/f25da7fb/2017-2018/matchlogs/c12/passing.
# Retrieving data from https://fbref.com/en/squads/f25da7fb/2017-2018/matchlogs/c12/passing_types.
# Retrieving data from https://fbref.com/en/squads/f25da7fb/2017-2018/matchlogs/c12/gca.
# Retrieving data from https://fbref.com/en/squads/f25da7fb/2017-2018/matchlogs/c12/defense.
# Retrieving data from https://fbref.com/en/squads/f25da7fb/2017-2018/matchlogs/c12/possession.
# Retrieving data from https://fbref.com/en/squads/f25da7fb/2017-2018/matchlogs/c12/misc.
# Starting data collection for squad 14/20: Alaves (id: 8d6fd021)
# Retrieving data from https://fbref.com/en/squads/8d6fd021/2017-2018/matchlogs/c12/schedule.
# Retrieving data from https://fbref.com/en/squads/8d6fd021/2017-2018/matchlogs/c12/shooting.
# Retrieving data from https://fbref.com/en/squads/8d6fd021/2017-2018/matchlogs/c12/keeper.
# Retrieving data from https://fbref.com/en/squads/8d6fd021/2017-2018/matchlogs/c12/passing.
# Retrieving data from https://fbref.com/en/squads/8d6fd021/2017-2018/matchlogs/c12/passing_types.
# Retrieving data from https://fbref.com/en/squads/8d6fd021/2017-2018/matchlogs/c12/gca.
# Retrieving data from https://fbref.com/en/squads/8d6fd021/2017-2018/matchlogs/c12/defense.
# Retrieving data from https://fbref.com/en/squads/8d6fd021/2017-2018/matchlogs/c12/possession.
# Retrieving data from https://fbref.com/en/squads/8d6fd021/2017-2018/matchlogs/c12/misc.
# Starting data collection for squad 15/20: Levante (id: 9800b6a1)
# Retrieving data from https://fbref.com/en/squads/9800b6a1/2017-2018/matchlogs/c12/schedule.
# Retrieving data from https://fbref.com/en/squads/9800b6a1/2017-2018/matchlogs/c12/shooting.
# Retrieving data from https://fbref.com/en/squads/9800b6a1/2017-2018/matchlogs/c12/keeper.
# Retrieving data from https://fbref.com/en/squads/9800b6a1/2017-2018/matchlogs/c12/passing.
# Retrieving data from https://fbref.com/en/squads/9800b6a1/2017-2018/matchlogs/c12/passing_types.
# Retrieving data from https://fbref.com/en/squads/9800b6a1/2017-2018/matchlogs/c12/gca.
# Retrieving data from https://fbref.com/en/squads/9800b6a1/2017-2018/matchlogs/c12/defense.
# Retrieving data from https://fbref.com/en/squads/9800b6a1/2017-2018/matchlogs/c12/possession.
# Retrieving data from https://fbref.com/en/squads/9800b6a1/2017-2018/matchlogs/c12/misc.
# Starting data collection for squad 16/20: Athletic Club (id: 2b390eca)
# Retrieving data from https://fbref.com/en/squads/2b390eca/2017-2018/matchlogs/c12/schedule.
# Retrieving data from https://fbref.com/en/squads/2b390eca/2017-2018/matchlogs/c12/shooting.
# Retrieving data from https://fbref.com/en/squads/2b390eca/2017-2018/matchlogs/c12/keeper.
# Retrieving data from https://fbref.com/en/squads/2b390eca/2017-2018/matchlogs/c12/passing.
# Retrieving data from https://fbref.com/en/squads/2b390eca/2017-2018/matchlogs/c12/passing_types.
# Retrieving data from https://fbref.com/en/squads/2b390eca/2017-2018/matchlogs/c12/gca.
# Retrieving data from https://fbref.com/en/squads/2b390eca/2017-2018/matchlogs/c12/defense.
# Retrieving data from https://fbref.com/en/squads/2b390eca/2017-2018/matchlogs/c12/possession.
# Retrieving data from https://fbref.com/en/squads/2b390eca/2017-2018/matchlogs/c12/misc.
# Starting data collection for squad 17/20: Leganes (id: 7c6f2c78)
# Retrieving data from https://fbref.com/en/squads/7c6f2c78/2017-2018/matchlogs/c12/schedule.
# Retrieving data from https://fbref.com/en/squads/7c6f2c78/2017-2018/matchlogs/c12/shooting.
# Retrieving data from https://fbref.com/en/squads/7c6f2c78/2017-2018/matchlogs/c12/keeper.
# Retrieving data from https://fbref.com/en/squads/7c6f2c78/2017-2018/matchlogs/c12/passing.
# Retrieving data from https://fbref.com/en/squads/7c6f2c78/2017-2018/matchlogs/c12/passing_types.
# Retrieving data from https://fbref.com/en/squads/7c6f2c78/2017-2018/matchlogs/c12/gca.
# Retrieving data from https://fbref.com/en/squads/7c6f2c78/2017-2018/matchlogs/c12/defense.
# Retrieving data from https://fbref.com/en/squads/7c6f2c78/2017-2018/matchlogs/c12/possession.
# Retrieving data from https://fbref.com/en/squads/7c6f2c78/2017-2018/matchlogs/c12/misc.
# Starting data collection for squad 18/20: Deportivo La Coruna (id: 2a60ed82)
# Retrieving data from https://fbref.com/en/squads/2a60ed82/2017-2018/matchlogs/c12/schedule.
# Retrieving data from https://fbref.com/en/squads/2a60ed82/2017-2018/matchlogs/c12/shooting.
# Retrieving data from https://fbref.com/en/squads/2a60ed82/2017-2018/matchlogs/c12/keeper.
# Retrieving data from https://fbref.com/en/squads/2a60ed82/2017-2018/matchlogs/c12/passing.
# Retrieving data from https://fbref.com/en/squads/2a60ed82/2017-2018/matchlogs/c12/passing_types.
# Retrieving data from https://fbref.com/en/squads/2a60ed82/2017-2018/matchlogs/c12/gca.
# Retrieving data from https://fbref.com/en/squads/2a60ed82/2017-2018/matchlogs/c12/defense.
# Retrieving data from https://fbref.com/en/squads/2a60ed82/2017-2018/matchlogs/c12/possession.
# Retrieving data from https://fbref.com/en/squads/2a60ed82/2017-2018/matchlogs/c12/misc.
# Starting data collection for squad 19/20: Las Palmas (id: 0049d422)
# Retrieving data from https://fbref.com/en/squads/0049d422/2017-2018/matchlogs/c12/schedule.
# Retrieving data from https://fbref.com/en/squads/0049d422/2017-2018/matchlogs/c12/shooting.
# Retrieving data from https://fbref.com/en/squads/0049d422/2017-2018/matchlogs/c12/keeper.
# Retrieving data from https://fbref.com/en/squads/0049d422/2017-2018/matchlogs/c12/passing.
# Retrieving data from https://fbref.com/en/squads/0049d422/2017-2018/matchlogs/c12/passing_types.
# Retrieving data from https://fbref.com/en/squads/0049d422/2017-2018/matchlogs/c12/gca.
# Retrieving data from https://fbref.com/en/squads/0049d422/2017-2018/matchlogs/c12/defense.
# Retrieving data from https://fbref.com/en/squads/0049d422/2017-2018/matchlogs/c12/possession.
# Retrieving data from https://fbref.com/en/squads/0049d422/2017-2018/matchlogs/c12/misc.
# Starting data collection for squad 20/20: Malaga (id: 1c896955)
# Retrieving data from https://fbref.com/en/squads/1c896955/2017-2018/matchlogs/c12/schedule.
# Retrieving data from https://fbref.com/en/squads/1c896955/2017-2018/matchlogs/c12/shooting.
# Retrieving data from https://fbref.com/en/squads/1c896955/2017-2018/matchlogs/c12/keeper.
# Retrieving data from https://fbref.com/en/squads/1c896955/2017-2018/matchlogs/c12/passing.
# Retrieving data from https://fbref.com/en/squads/1c896955/2017-2018/matchlogs/c12/passing_types.
# Retrieving data from https://fbref.com/en/squads/1c896955/2017-2018/matchlogs/c12/gca.
# Retrieving data from https://fbref.com/en/squads/1c896955/2017-2018/matchlogs/c12/defense.
# Retrieving data from https://fbref.com/en/squads/1c896955/2017-2018/matchlogs/c12/possession.
# Retrieving data from https://fbref.com/en/squads/1c896955/2017-2018/matchlogs/c12/misc.

# %%
print(df.shape)
df.head()
# Out:
# (760, 170)
#   schedule_Date schedule_Time schedule_Round schedule_Day schedule_Venue  \
# 0    2017-08-20         20:15    Matchweek 1          Sun           Home
# 1    2017-08-26         18:15    Matchweek 2          Sat           Away
# 2    2017-09-09         20:45    Matchweek 3          Sat           Home
# 3    2017-09-16         16:15    Matchweek 4          Sat           Away
# 4    2017-09-19         22:00    Matchweek 5          Tue           Home
#
#   schedule_Result  schedule_GF  schedule_GA schedule_Opponent  schedule_xG  \
# 0               W            2            0             Betis          1.1
# 1               W            2            0            Alavés          2.5
# 2               W            5            0          Espanyol          5.1
# 3               W            2            1            Getafe          0.4
# 4               W            6            1             Eibar          2.4
#
#    ...  misc_performance_Crs  misc_performance_Int  misc_performance_TklW  \
# 0  ...                    10                    12                     10
# 1  ...                    18                     8                     10
# 2  ...                     9                     6                     10
# 3  ...                    10                    16                     12
# 4  ...                     8                     9                     14
#
#   misc_performance_PKwon misc_performance_PKcon misc_performance_OG  \
# 0                      0                      0                   0
# 1                      1                      0                   0
# 2                      0                      0                   0
# 3                      0                      0                   0
# 4                      1                      0                   0
#
#   misc_performance_Recov  misc_aerialduels_Won misc_aerialduels_Lost  \
# 0                     55                     3                     5
# 1                     57                     6                     8
# 2                     49                     9                     5
# 3                     37                     4                    10
# 4                     54                     6                    11
#
#    misc_aerialduels_Won%
# 0                   37.5
# 1                   42.9
# 2                   64.3
# 3                   28.6
# 4                   35.3
#
# [5 rows x 170 columns]
