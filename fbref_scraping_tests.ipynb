# %%
from fbref_scraping import Fbref

squad_index = "18bb7c10" # 18bb7c10 -> Arsenal
season_start_year = 2021
league_index = 9 # 9 -> Premier League

# create scraper class instance
scraper = Fbref()

# test .get_squad_match_data_df()
df = scraper.get_squad_match_data_df(squad_index, league_index, season_start_year, print_logs=True)
# Out:
# Retrieving data from https://fbref.com/en/squads/18bb7c10/2021-2022/matchlogs/c9/schedule
# Retrieving data from https://fbref.com/en/squads/18bb7c10/2021-2022/matchlogs/c9/shooting
# Retrieving data from https://fbref.com/en/squads/18bb7c10/2021-2022/matchlogs/c9/keeper
# Retrieving data from https://fbref.com/en/squads/18bb7c10/2021-2022/matchlogs/c9/passing
# Retrieving data from https://fbref.com/en/squads/18bb7c10/2021-2022/matchlogs/c9/passing_types
# Retrieving data from https://fbref.com/en/squads/18bb7c10/2021-2022/matchlogs/c9/gca
# Retrieving data from https://fbref.com/en/squads/18bb7c10/2021-2022/matchlogs/c9/defense
# Retrieving data from https://fbref.com/en/squads/18bb7c10/2021-2022/matchlogs/c9/possession
# Retrieving data from https://fbref.com/en/squads/18bb7c10/2021-2022/matchlogs/c9/misc

# %%
df.shape
# Out:
# (38, 170)

# %%
df
# Out:
#    schedule_Date schedule_Time schedule_Round schedule_Day schedule_Venue  \
# 0     2021-08-13         20:00    Matchweek 1          Fri           Away
# 1     2021-08-22         16:30    Matchweek 2          Sun           Home
# 2     2021-08-28         12:30    Matchweek 3          Sat           Away
# 3     2021-09-11         15:00    Matchweek 4          Sat           Home
# 4     2021-09-18         15:00    Matchweek 5          Sat           Away
# 5     2021-09-26         16:30    Matchweek 6          Sun           Home
# 6     2021-10-02         17:30    Matchweek 7          Sat           Away
# 7     2021-10-18         20:00    Matchweek 8          Mon           Home
# 8     2021-10-22         20:00    Matchweek 9          Fri           Home
# 9     2021-10-30         12:30   Matchweek 10          Sat           Away
# 10    2021-11-07         14:00   Matchweek 11          Sun           Home
# 11    2021-11-20         17:30   Matchweek 12          Sat           Away
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# schedule_Date
# schedule_Time
# schedule_Round
# schedule_Day
# schedule_Venue
# schedule_Result
# schedule_GF
# schedule_GA
# schedule_Opponent
# schedule_xG
# schedule_xGA
# schedule_Poss
# schedule_Attendance
# schedule_Captain
# schedule_Formation
# schedule_Referee
# schedule_Match Report
# schedule_Notes
# schedule_fbref_season
# schedule_fbref_league_id
# schedule_fbref_squad_id
# schedule_fbref_opponent_id
# schedule_fbref_match_id
# shooting_standard_Gls
# shooting_standard_Sh
# shooting_standard_SoT
# shooting_standard_SoT%
# shooting_standard_G/Sh
# shooting_standard_G/SoT
# shooting_standard_Dist
# shooting_standard_FK
# shooting_standard_PK
# shooting_standard_PKatt
# shooting_expected_xG
# shooting_expected_npxG
# shooting_expected_npxG/Sh
# shooting_expected_G-xG
# shooting_expected_np:G-xG
# keeper_performance_SoTA
# keeper_performance_GA
# keeper_performance_Saves
# keeper_performance_Save%
# keeper_performance_CS
# keeper_performance_PSxG
# ...
